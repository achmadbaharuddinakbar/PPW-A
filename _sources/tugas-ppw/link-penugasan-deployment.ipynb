# %% [markdown]
# # **Link Penugasan Deployment**

# %% [markdown]
# **Nama : Achmad Baharuddin Akbar**
#
# **NIM  : 210411100001**

# %% [markdown]
# Tugas 3 - Klasifikasi Logistic regression : https://huggingface.co/spaces/akbar001/klasifikasi-logreg
#
# Tugas 4 - Graph : https://huggingface.co/spaces/akbar001/graph
#
# Tugas 7 - Klasifikasi Logistic Regression + SVD : https://huggingface.co/spaces/akbar001/klasifikasi-logreg-svd
#
# Tugas 8 - Clustering dengan Fuzzy Cmeans : https://huggingface.co/spaces/akbar001/fuzzy-cmeans-klasifikasi
